# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

def take():
    print("Pengecekkan Fungsi Parameter Terhadap Berbagai Kesibukkan yang dapat dialami oleh 345")



take()
# Out:
# Pengecekkan Fungsi Parameter Terhadap Berbagai Kesibukkan yang dapat dialami oleh 345

# %%
import numpy as np

print("Hello World!")

a = 5
b = "Halo"
c = False
d = 7.5
e = 'a'
# Out:
# Hello World!

# %%
x = np.linspace(-2,2,500)
y = x**2

line1 = plt.plot(x,y, 'g-')
plt.title("Square Function")
plt.xlabel("x")
plt.ylabel("y=x**2")
plt.grid(True)
plt.savefig("My Figure")
plt.show()

# %%
x = np.linspace(-1.4, 1.4, 500)

plt.figure(1)
plt.subplot(2,2,1)
plt.plot(x, x)
plt.subplot(2, 2, 2)  # 2 rows, 2 columns, 2nd subplot = top right
plt.plot(x, x**2)
plt.subplot(2, 1,2)  # 2 rows, 2 columns, 3rd subplot = bottom left
plt.plot(x, x**3)
plt.show()

plt.figure(2)
plt.subplot(2, 1,2, projection="3d")  # 2 rows, 2 columns, 3rd subplot = bottom left
plt.plot(x, x**3)
plt.show()
plt.show()

# %%
a = np.random.rand(3,10)
print(a)
# Out:
# [[0.52842355 0.29218092 0.79192339 0.12423837 0.29224915 0.52921599
#   0.08534637 0.72159271 0.67417444 0.45905469]
#  [0.53397767 0.09044711 0.85925397 0.51352807 0.67295139 0.48108671
#   0.64427915 0.76006731 0.67841469 0.53767213]
#  [0.61556998 0.00632258 0.04955714 0.87729451 0.76133469 0.03747485
#   0.20330007 0.38386096 0.55844677 0.72683669]]

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
x = np.linspace(-2, 2, 200)
fig1, (ax_top, ax_bottom) = plt.subplots(2, 1)
fig1.set_size_inches(10,5)
line1, line2 = ax_top.plot(x, np.sin(3*x**2), "r-", x, np.cos(5*x**2), "b-")
line3, = ax_bottom.plot(x, np.sin(3*x), "r-")
ax_top.grid(True)

fig2, ax = plt.subplots(1, 1)
ax.plot(x, x**2)
plt.show()

# %%
x = np.linspace(-1.5, 1.5, 30)
px = 0.8
py = px**2

plt.plot(x, x**2, "b-", px, py, "ro")

plt.text(0, 1.5, "Square function\n$y = x^2$", fontsize=20, color='blue',
         horizontalalignment="center")
plt.text(0,0,"Hello", ha="center")
plt.text(px - 0.8, py, "Beautiful point", weight="heavy", ha="center")
plt.text(px + 0.05, py - 0.4, "x = %0.2f\ny = %0.2f"%(px, py), rotation=-30,
         color='gray')

plt.show()

# %%
x = np.linspace(-2, 2, 100)

plt.figure(1, figsize=(15,10))
plt.subplot(131)
plt.plot(x, x**3)
plt.grid(True)
plt.title("Default ticks")

ax = plt.subplot(132)
plt.plot(x, x**3)
ax.yaxis.set_tickslabels(["min",4,3,2,1, "max"])
plt.grid(True)
plt.title("Manual ticks on the x-axis")

ax = plt.subplot(133)
plt.plot(x, x**3)
plt.minorticks_on()
ax.tick_params(axis='x', which='minor', bottom=False)
ax.xaxis.set_ticks([-2, 0, 1, 2])
ax.yaxis.set_ticks(np.arange(-5, 5, 1))
ax.yaxis.set_ticklabels(["min", -4, -3, -2, -1, 0, 1, 2, 3, "max"])
plt.grid(True)
plt.title("Manual ticks and tick labels\n(plus minor ticks) on the y-axis")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 11
#       9 ax = plt.subplot(132)
#      10 plt.plot(x, x**3)
# ---> 11 ax.yaxis.set_tickslabels(["min",4,3,2,1, "max"])
#      12 plt.grid(True)
#      13 plt.title("Manual ticks on the x-axis")
#
# AttributeError: 'YAxis' object has no attribute 'set_tickslabels'

# %%
radius = 1
theta = np.linspace(0, 2*np.pi*radius, 1000)

plt.subplot(111, projection='polar')
plt.plot(theta, np.sin(5*theta), "g-")
plt.plot(theta, 0.5*np.cos(20*theta), "b-")
plt.show()
